# %% [markdown]
# # Word Embedding for Sequence Processing

# %% [markdown]
# **The goal of this practical is to use pre-trained word embedding for adressing the sequence prediction tasks studied in week 2: PoS and chunking.**

# %%
import numpy as np
import gensim.downloader as api
from gensim.models import KeyedVectors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive
# Out:
# <module 'google.colab.drive' from '/usr/local/lib/python3.10/dist-packages/google/colab/drive.py'>

# %% [markdown]
# ## 0) Loading PoS (or chunking) datasets (small or large)

# %%
def load(filename):
    listeDoc = list()
    with open(filename, "r") as f:
        doc = list()
        for ligne in f:
            #print "l : ",len(ligne)," ",ligne
            if len(ligne) < 2: # fin de doc
                listeDoc.append(doc)
                doc = list()
                continue
            mots = ligne.replace("\n","").split(" ")
            doc.append((mots[0],mots[2])) # mettre mots[2] à la place de mots[1] pour le chuncking
    return listeDoc

# %%
bSmall = False

if(bSmall==True):
    filename = "/content/drive/My Drive/chtrain.txt"
    filenameT = "/content/drive/My Drive/chtest.txt"

else:
    # Larger corpus .
    filename = "/content/drive/My Drive/train.txt"
    filenameT = "/content/drive/My Drive/test.txt"

alldocs = load(filename)
alldocsT = load(filenameT)

print(len(alldocs)," docs read")
print(len(alldocsT)," docs (T) read")
# Out:
# 8936  docs read
# 2012  docs (T) read

# %% [markdown]
# # 1) Word embedding for classifying each word

# %% [markdown]
# ### Pre-trained word2vec

# %%
import gensim.downloader as api
bload = True
fname = "word2vec-google-news-300"
sdir = "/content/drive/My Drive/" # Change

if(bload==True):
    wv_pre_trained = KeyedVectors.load(sdir+fname+".dat")
else:
    wv_pre_trained = api.load(fname)
    wv_pre_trained.save(sdir+fname+".dat")

# %% [markdown]
# ### Some token on the dataset are missing, we will encode them with a random vector
# This is sub-optimal, but we need to do something

# %%
def randomvec():
    default = np.random.randn(300)
    default = default  / np.linalg.norm(default)
    return default

# %%
np.random.seed(seed=10) # seed the randomness

dictadd = dict()
cpt=0
for d in alldocs:
    cpt+=1
    print(" ****** Document ******",cpt)
    for (x,pos) in d:
        if (not (x in wv_pre_trained) and not (x in dictadd)):
            print(x," not in WE, adding it with random vector")
            dictadd[x] = randomvec()

for d in alldocsT:
    cpt+=1
    print(" ****** TEST Document ******",cpt)
    for (x,pos) in d:
        if (not (x in wv_pre_trained) and not (x in dictadd)):
            print(x," not in WE, adding it with random vector")
            dictadd[x] = randomvec()
            #wv_pre_trained.add_vector(x,randomvec())
# Out:
# Streaming output truncated to the last 5000 lines.
#  ****** Document ****** 7149
#  ****** Document ****** 7150
#  ****** Document ****** 7151
#  ****** Document ****** 7152
#  ****** Document ****** 7153
#  ****** Document ****** 7154
#  ****** Document ****** 7155
#  ****** Document ****** 7156
# 409  not in WE, adding it with random vector
#  ****** Document ****** 7157
#  ****** Document ****** 7158
#  ****** Document ****** 7159
#  ****** Document ****** 7160
#  ****** Document ****** 7161
#  ****** Document ****** 7162
# 122  not in WE, adding it with random vector
#  ****** Document ****** 7163
#  ****** Document ****** 7164
#  ****** Document ****** 7165
#  ****** Document ****** 7166
#  ****** Document ****** 7167
#  ****** Document ****** 7168
# school-lunch  not in WE, adding it with random vector
#  ****** Document ****** 7169
# emergency-relief  not in WE, adding it with random vector
#  ****** Document ****** 7170
#  ****** Document ****** 7171
#  ****** Document ****** 7172
# follow-on  not in WE, adding it with random vector
#  ****** Document ****** 7173
#  ****** Document ****** 7174
#  ****** Document ****** 7175
#  ****** Document ****** 7176
#  ****** Document ****** 7177
#  ****** Document ****** 7178
#  ****** Document ****** 7179
#  ****** Document ****** 7180
#  ****** Document ****** 7181
#  ****** Document ****** 7182
# money-wise  not in WE, adding it with random vector
#  ****** Document ****** 7183
#  ****** Document ****** 7184
#  ****** Document ****** 7185
# Twenty-five  not in WE, adding it with random vector
#  ****** Document ****** 7186
#  ****** Document ****** 7187
#  ****** Document ****** 7188
#  ****** Document ****** 7189
#  ****** Document ****** 7190
# community-development  not in WE, adding it with random vector
#  ****** Document ****** 7191
#  ****** Document ****** 7192
#  ****** Document ****** 7193
#  ****** Document ****** 7194
#  ****** Document ****** 7195
#  ****** Document ****** 7196
#  ****** Document ****** 7197
#  ****** Document ****** 7198
#  ****** Document ****** 7199
#  ****** Document ****** 7200
# medical-airlift  not in WE, adding it with random vector
#  ****** Document ****** 7201
#  ****** Document ****** 7202
#  ****** Document ****** 7203
#  ****** Document ****** 7204
# one-page  not in WE, adding it with random vector
#  ****** Document ****** 7205
#  ****** Document ****** 7206
#  ****** Document ****** 7207
#  ****** Document ****** 7208
#  ****** Document ****** 7209
#  ****** Document ****** 7210
#  ****** Document ****** 7211
#  ****** Document ****** 7212
#  ****** Document ****** 7213
#  ****** Document ****** 7214
#  ****** Document ****** 7215
#  ****** Document ****** 7216
#  ****** Document ****** 7217
# drought-ravaged  not in WE, adding it with random vector
# 7.45  not in WE, adding it with random vector
#  ****** Document ****** 7218
#  ****** Document ****** 7219
#  ****** Document ****** 7220
#  ****** Document ****** 7221
#  ****** Document ****** 7222
#  ****** Document ****** 7223
#  ****** Document ****** 7224
#  ****** Document ****** 7225
#  ****** Document ****** 7226
# Pankyo  not in WE, adding it with random vector
#  ****** Document ****** 7227
#  ****** Document ****** 7228
#  ****** Document ****** 7229
#  ****** Document ****** 7230
#  ****** Document ****** 7231
#  ****** Document ****** 7232
#  ****** Document ****** 7233
#  ****** Document ****** 7234
#  ****** Document ****** 7235
#  ****** Document ****** 7236
#  ****** Document ****** 7237
#  ****** Document ****** 7238
#  ****** Document ****** 7239
#  ****** Document ****** 7240
# ODDITIES  not in WE, adding it with random vector
#  ****** Document ****** 7241
# CD-ROM  not in WE, adding it with random vector
#  ****** Document ****** 7242
#  ****** Document ****** 7243
# tongue-in-cheek  not in WE, adding it with random vector
#  ****** Document ****** 7244
#  ****** Document ****** 7245
#  ****** Document ****** 7246
#  ****** Document ****** 7247
#  ****** Document ****** 7248
# tax-deductible  not in WE, adding it with random vector
#  ****** Document ****** 7249
#  ****** Document ****** 7250
#  ****** Document ****** 7251
#  ****** Document ****** 7252
#  ****** Document ****** 7253
#  ****** Document ****** 7254
#  ****** Document ****** 7255
#  ****** Document ****** 7256
#  ****** Document ****** 7257
#  ****** Document ****** 7258
#  ****** Document ****** 7259
# 11th-hour  not in WE, adding it with random vector
#  ****** Document ****** 7260
#  ****** Document ****** 7261
#  ****** Document ****** 7262
#  ****** Document ****** 7263
# L.L.  not in WE, adding it with random vector
#  ****** Document ****** 7264
#  ****** Document ****** 7265
#  ****** Document ****** 7266
#  ****** Document ****** 7267
# Amcap  not in WE, adding it with random vector
#  ****** Document ****** 7268
#  ****** Document ****** 7269
#  ****** Document ****** 7270
# most-livable  not in WE, adding it with random vector
# soot-stained  not in WE, adding it with random vector
#  ****** Document ****** 7271
# personal-care  not in WE, adding it with random vector
#  ****** Document ****** 7272
# 329  not in WE, adding it with random vector
#  ****** Document ****** 7273
# Unamused  not in WE, adding it with random vector
# T-shirts  not in WE, adding it with random vector
#  ****** Document ****** 7274
#  ****** Document ****** 7275
#  ****** Document ****** 7276
#  ****** Document ****** 7277
#  ****** Document ****** 7278
#  ****** Document ****** 7279
#  ****** Document ****** 7280
#  ****** Document ****** 7281
#  ****** Document ****** 7282
#  ****** Document ****** 7283
#  ****** Document ****** 7284
#  ****** Document ****** 7285
# Co-authors  not in WE, adding it with random vector
#  ****** Document ****** 7286
#  ****** Document ****** 7287
# Anaheim-Santa  not in WE, adding it with random vector
# Nassau-Suffolk  not in WE, adding it with random vector
#  ****** Document ****** 7288
#  ****** Document ****** 7289
#  ****** Document ****** 7290
#  ****** Document ****** 7291
#  ****** Document ****** 7292
#  ****** Document ****** 7293
# 76.5  not in WE, adding it with random vector
# 1.83  not in WE, adding it with random vector
#  ****** Document ****** 7294
# B-2  not in WE, adding it with random vector
# research-and-development  not in WE, adding it with random vector
#  ****** Document ****** 7295
# 28.8  not in WE, adding it with random vector
#  ****** Document ****** 7296
#  ****** Document ****** 7297
# 2.52  not in WE, adding it with random vector
# 2.29  not in WE, adding it with random vector
#  ****** Document ****** 7298
# 76.4  not in WE, adding it with random vector
#  ****** Document ****** 7299
#  ****** Document ****** 7300
# F\/A-18  not in WE, adding it with random vector
#  ****** Document ****** 7301
# 21.125  not in WE, adding it with random vector
#  ****** Document ****** 7302
# 54.875  not in WE, adding it with random vector
#  ****** Document ****** 7303
#  ****** Document ****** 7304
# ALQ-135  not in WE, adding it with random vector
# F-15  not in WE, adding it with random vector
#  ****** Document ****** 7305
#  ****** Document ****** 7306
#  ****** Document ****** 7307
# 5.16  not in WE, adding it with random vector
#  ****** Document ****** 7308
# 46.9  not in WE, adding it with random vector
# 190.3  not in WE, adding it with random vector
# 4.05  not in WE, adding it with random vector
#  ****** Document ****** 7309
# 3.92  not in WE, adding it with random vector
#  ****** Document ****** 7310
# cost-sharing  not in WE, adding it with random vector
#  ****** Document ****** 7311
#  ****** Document ****** 7312
# 16.5  not in WE, adding it with random vector
# 15.8  not in WE, adding it with random vector
#  ****** Document ****** 7313
# 12.4  not in WE, adding it with random vector
#  ****** Document ****** 7314
# 210.3  not in WE, adding it with random vector
# 5.03  not in WE, adding it with random vector
# 208.8  not in WE, adding it with random vector
# 4.97  not in WE, adding it with random vector
# 4.9  not in WE, adding it with random vector
# 7.41  not in WE, adding it with random vector
# 7.06  not in WE, adding it with random vector
#  ****** Document ****** 7315
# 1-2-3  not in WE, adding it with random vector
#  ****** Document ****** 7316
# product-launch  not in WE, adding it with random vector
#  ****** Document ****** 7317
# 32.50  not in WE, adding it with random vector
#  ****** Document ****** 7318
# 153.9  not in WE, adding it with random vector
#  ****** Document ****** 7319
# 116.8  not in WE, adding it with random vector
#  ****** Document ****** 7320
# 38.5  not in WE, adding it with random vector
# 92  not in WE, adding it with random vector
# 1.08  not in WE, adding it with random vector
#  ****** Document ****** 7321
# 356  not in WE, adding it with random vector
#  ****** Document ****** 7322
#  ****** Document ****** 7323
#  ****** Document ****** 7324
# manufacturing-cost  not in WE, adding it with random vector
#  ****** Document ****** 7325
#  ****** Document ****** 7326
# 315,000  not in WE, adding it with random vector
#  ****** Document ****** 7327
#  ****** Document ****** 7328
# four-to-one  not in WE, adding it with random vector
#  ****** Document ****** 7329
#  ****** Document ****** 7330
# high-tech  not in WE, adding it with random vector
#  ****** Document ****** 7331
#  ****** Document ****** 7332
#  ****** Document ****** 7333
# Kurlak  not in WE, adding it with random vector
#  ****** Document ****** 7334
#  ****** Document ****** 7335
#  ****** Document ****** 7336
#  ****** Document ****** 7337
#  ****** Document ****** 7338
# 3090  not in WE, adding it with random vector
#  ****** Document ****** 7339
#  ****** Document ****** 7340
#  ****** Document ****** 7341
#  ****** Document ****** 7342
#  ****** Document ****** 7343
#  ****** Document ****** 7344
#  ****** Document ****** 7345
#  ****** Document ****** 7346
#  ****** Document ****** 7347
#  ****** Document ****** 7348
#  ****** Document ****** 7349
#  ****** Document ****** 7350
#  ****** Document ****** 7351
#  ****** Document ****** 7352
#  ****** Document ****** 7353
#  ****** Document ****** 7354
#  ****** Document ****** 7355
#  ****** Document ****** 7356
# just-in-time  not in WE, adding it with random vector
#  ****** Document ****** 7357
#  ****** Document ****** 7358
#  ****** Document ****** 7359
# disaster-recovery  not in WE, adding it with random vector
#  ****** Document ****** 7360
#  ****** Document ****** 7361
# self-diagnostic  not in WE, adding it with random vector
#  ****** Document ****** 7362
#  ****** Document ****** 7363
#  ****** Document ****** 7364
#  ****** Document ****** 7365
# show-stoppers  not in WE, adding it with random vector
# 150-plus  not in WE, adding it with random vector
# one-square-mile  not in WE, adding it with random vector
#  ****** Document ****** 7366
#  ****** Document ****** 7367
# 10.59  not in WE, adding it with random vector
#  ****** Document ****** 7368
#  ****** Document ****** 7369
#  ****** Document ****** 7370
#  ****** Document ****** 7371
#  ****** Document ****** 7372
#  ****** Document ****** 7373
#  ****** Document ****** 7374
#  ****** Document ****** 7375
# Egg-industry  not in WE, adding it with random vector
# egg-breaking  not in WE, adding it with random vector
#  ****** Document ****** 7376
#  ****** Document ****** 7377
# 46-year-old  not in WE, adding it with random vector
#  ****** Document ****** 7378
#  ****** Document ****** 7379
#  ****** Document ****** 7380
#  ****** Document ****** 7381
#  ****** Document ****** 7382
#  ****** Document ****** 7383
# 30-pound  not in WE, adding it with random vector
#  ****** Document ****** 7384
#  ****** Document ****** 7385
#  ****** Document ****** 7386
# R2-D2  not in WE, adding it with random vector
#  ****** Document ****** 7387
# 3,390  not in WE, adding it with random vector
#  ****** Document ****** 7388
# 1890s  not in WE, adding it with random vector
#  ****** Document ****** 7389
#  ****** Document ****** 7390
#  ****** Document ****** 7391
#  ****** Document ****** 7392
#  ****** Document ****** 7393
#  ****** Document ****** 7394
#  ****** Document ****** 7395
#  ****** Document ****** 7396
#  ****** Document ****** 7397
#  ****** Document ****** 7398
#  ****** Document ****** 7399
#  ****** Document ****** 7400
#  ****** Document ****** 7401
#  ****** Document ****** 7402
#  ****** Document ****** 7403
#  ****** Document ****** 7404
#  ****** Document ****** 7405
# egg-processing  not in WE, adding it with random vector
#  ****** Document ****** 7406
#  ****** Document ****** 7407
#  ****** Document ****** 7408
#  ****** Document ****** 7409
#  ****** Document ****** 7410
#  ****** Document ****** 7411
#  ****** Document ****** 7412
#  ****** Document ****** 7413
#  ****** Document ****** 7414
#  ****** Document ****** 7415
#  ****** Document ****** 7416
#  ****** Document ****** 7417
#  ****** Document ****** 7418
#  ****** Document ****** 7419
# Adsi  not in WE, adding it with random vector
#  ****** Document ****** 7420
#  ****** Document ****** 7421
#  ****** Document ****** 7422
#  ****** Document ****** 7423
#  ****** Document ****** 7424
#  ****** Document ****** 7425
#  ****** Document ****** 7426
#  ****** Document ****** 7427
#  ****** Document ****** 7428
# show-biz  not in WE, adding it with random vector
#  ****** Document ****** 7429
#  ****** Document ****** 7430
# coming-of-age  not in WE, adding it with random vector
# '40s  not in WE, adding it with random vector
#  ****** Document ****** 7431
#  ****** Document ****** 7432
#  ****** Document ****** 7433
#  ****** Document ****** 7434
#  ****** Document ****** 7435
#  ****** Document ****** 7436
#  ****** Document ****** 7437
# banquet-hall  not in WE, adding it with random vector
#  ****** Document ****** 7438
#  ****** Document ****** 7439
#  ****** Document ****** 7440
#  ****** Document ****** 7441
#  ****** Document ****** 7442
# face-to-face  not in WE, adding it with random vector
#  ****** Document ****** 7443
# time-hotels  not in WE, adding it with random vector
#  ****** Document ****** 7444
#  ****** Document ****** 7445
#  ****** Document ****** 7446
#  ****** Document ****** 7447
#  ****** Document ****** 7448
#  ****** Document ****** 7449
#  ****** Document ****** 7450
#  ****** Document ****** 7451
# off-hours  not in WE, adding it with random vector
#  ****** Document ****** 7452
#  ****** Document ****** 7453
#  ****** Document ****** 7454
#  ****** Document ****** 7455
#  ****** Document ****** 7456
#  ****** Document ****** 7457
#  ****** Document ****** 7458
# tweety-bird  not in WE, adding it with random vector
#  ****** Document ****** 7459
#  ****** Document ****** 7460
#  ****** Document ****** 7461
#  ****** Document ****** 7462
#  ****** Document ****** 7463
#  ****** Document ****** 7464
#  ****** Document ****** 7465
#  ****** Document ****** 7466
# 2,850,000  not in WE, adding it with random vector
#  ****** Document ****** 7467
#  ****** Document ****** 7468
#  ****** Document ****** 7469
#  ****** Document ****** 7470
# 13.625  not in WE, adding it with random vector
#  ****** Document ****** 7471
#  ****** Document ****** 7472
# 115,000-square-foot  not in WE, adding it with random vector
#  ****** Document ****** 7473
#  ****** Document ****** 7474
# 589  not in WE, adding it with random vector
#  ****** Document ****** 7475
# F-14  not in WE, adding it with random vector
#  ****** Document ****** 7476
#  ****** Document ****** 7477
#  ****** Document ****** 7478
#  ****** Document ****** 7479
#  ****** Document ****** 7480
# Himont  not in WE, adding it with random vector
# 81%-owned  not in WE, adding it with random vector
# S.p  not in WE, adding it with random vector
#  ****** Document ****** 7481
# Galveston-Houston  not in WE, adding it with random vector
# 3,950  not in WE, adding it with random vector
#  ****** Document ****** 7482
# 421  not in WE, adding it with random vector
# 6.71  not in WE, adding it with random vector
#  ****** Document ****** 7483
#  ****** Document ****** 7484
#  ****** Document ****** 7485
#  ****** Document ****** 7486
#  ****** Document ****** 7487
#  ****** Document ****** 7488
# 66.5  not in WE, adding it with random vector
#  ****** Document ****** 7489
#  ****** Document ****** 7490
#  ****** Document ****** 7491
#  ****** Document ****** 7492
#  ****** Document ****** 7493
# 62.5  not in WE, adding it with random vector
#  ****** Document ****** 7494
#  ****** Document ****** 7495
#  ****** Document ****** 7496
#  ****** Document ****** 7497
#  ****** Document ****** 7498
#  ****** Document ****** 7499
#  ****** Document ****** 7500
#  ****** Document ****** 7501
#  ****** Document ****** 7502
#  ****** Document ****** 7503
# well-operated  not in WE, adding it with random vector
#  ****** Document ****** 7504
#  ****** Document ****** 7505
#  ****** Document ****** 7506
#  ****** Document ****** 7507
#  ****** Document ****** 7508
# money-laundering  not in WE, adding it with random vector
#  ****** Document ****** 7509
#  ****** Document ****** 7510
#  ****** Document ****** 7511
#  ****** Document ****** 7512
#  ****** Document ****** 7513
#  ****** Document ****** 7514
#  ****** Document ****** 7515
#  ****** Document ****** 7516
# 56-year-old  not in WE, adding it with random vector
#  ****** Document ****** 7517
#  ****** Document ****** 7518
# Money-market  not in WE, adding it with random vector
#  ****** Document ****** 7519
# Money-fund  not in WE, adding it with random vector
# 348.4  not in WE, adding it with random vector
# IBC\/Donoghue  not in WE, adding it with random vector
# Mass.-based  not in WE, adding it with random vector
#  ****** Document ****** 7520
#  ****** Document ****** 7521
#  ****** Document ****** 7522
#  ****** Document ****** 7523
#  ****** Document ****** 7524
#  ****** Document ****** 7525
#  ****** Document ****** 7526
#  ****** Document ****** 7527
#  ****** Document ****** 7528
# 190.58  not in WE, adding it with random vector
#  ****** Document ****** 7529
#  ****** Document ****** 7530
#  ****** Document ****** 7531
#  ****** Document ****** 7532
#  ****** Document ****** 7533
#  ****** Document ****** 7534
#  ****** Document ****** 7535
#  ****** Document ****** 7536
#  ****** Document ****** 7537
#  ****** Document ****** 7538
# 8.21  not in WE, adding it with random vector
# 8.26  not in WE, adding it with random vector
#  ****** Document ****** 7539
# 8.27  not in WE, adding it with random vector
# 8.61  not in WE, adding it with random vector
#  ****** Document ****** 7540
#  ****** Document ****** 7541
# 12.75  not in WE, adding it with random vector
#  ****** Document ****** 7542
#  ****** Document ****** 7543
# 9.33  not in WE, adding it with random vector
#  ****** Document ****** 7544
# 9.51  not in WE, adding it with random vector
#  ****** Document ****** 7545
# Paris-based  not in WE, adding it with random vector
#  ****** Document ****** 7546
#  ****** Document ****** 7547
#  ****** Document ****** 7548
#  ****** Document ****** 7549
#  ****** Document ****** 7550
#  ****** Document ****** 7551
#  ****** Document ****** 7552
# 318.6  not in WE, adding it with random vector
#  ****** Document ****** 7553
# 43.5  not in WE, adding it with random vector
# 68.5  not in WE, adding it with random vector
#  ****** Document ****** 7554
#  ****** Document ****** 7555
#  ****** Document ****** 7556
# EWDB  not in WE, adding it with random vector
#  ****** Document ****** 7557
#  ****** Document ****** 7558
#  ****** Document ****** 7559
#  ****** Document ****** 7560
#  ****** Document ****** 7561
# top-10  not in WE, adding it with random vector
#  ****** Document ****** 7562
#  ****** Document ****** 7563
#  ****** Document ****** 7564
#  ****** Document ****** 7565
#  ****** Document ****** 7566
# 660  not in WE, adding it with random vector
# 24th-largest  not in WE, adding it with random vector
#  ****** Document ****** 7567
# 14th  not in WE, adding it with random vector
#  ****** Document ****** 7568
#  ****** Document ****** 7569
# packaged-goods  not in WE, adding it with random vector
#  ****** Document ****** 7570
#  ****** Document ****** 7571
#  ****** Document ****** 7572
# Colgate-Palmolive  not in WE, adding it with random vector
#  ****** Document ****** 7573
#  ****** Document ****** 7574
# media-buying  not in WE, adding it with random vector
#  ****** Document ****** 7575
#  ****** Document ****** 7576
# 14.99  not in WE, adding it with random vector
#  ****** Document ****** 7577
#  ****** Document ****** 7578
#  ****** Document ****** 7579
#  ****** Document ****** 7580
# multimillion-dollar  not in WE, adding it with random vector
#  ****** Document ****** 7581
# media-related  not in WE, adding it with random vector
#  ****** Document ****** 7582
#  ****** Document ****** 7583
#  ****** Document ****** 7584
#  ****** Document ****** 7585
# large-scale  not in WE, adding it with random vector
#  ****** Document ****** 7586
#  ****** Document ****** 7587
# space-buying  not in WE, adding it with random vector
#  ****** Document ****** 7588
#  ****** Document ****** 7589
# Euroconvertible  not in WE, adding it with random vector
#  ****** Document ****** 7590
#  ****** Document ****** 7591
#  ****** Document ****** 7592
# new-business  not in WE, adding it with random vector
#  ****** Document ****** 7593
# Chiat\/Day\/Mojo  not in WE, adding it with random vector
#  ****** Document ****** 7594
#  ****** Document ****** 7595
#  ****** Document ****** 7596
#  ****** Document ****** 7597
#  ****** Document ****** 7598
#  ****** Document ****** 7599
#  ****** Document ****** 7600
#  ****** Document ****** 7601
#  ****** Document ****** 7602
# Chesebrough-Pond  not in WE, adding it with random vector
#  ****** Document ****** 7603
#  ****** Document ****** 7604
#  ****** Document ****** 7605
#  ****** Document ****** 7606
# McCann-Erickson  not in WE, adding it with random vector
#  ****** Document ****** 7607
#  ****** Document ****** 7608
# BOZELL  not in WE, adding it with random vector
#  ****** Document ****** 7609
#  ****** Document ****** 7610
#  ****** Document ****** 7611
# AC&R  not in WE, adding it with random vector
#  ****** Document ****** 7612
# AC&R\/CCL  not in WE, adding it with random vector
#  ****** Document ****** 7613
#  ****** Document ****** 7614
#  ****** Document ****** 7615
# Sibra  not in WE, adding it with random vector
#  ****** Document ****** 7616
#  ****** Document ****** 7617
#  ****** Document ****** 7618
#  ****** Document ****** 7619
# Diamond-Star  not in WE, adding it with random vector
# U.S.-built  not in WE, adding it with random vector
#  ****** Document ****** 7620
#  ****** Document ****** 7621
#  ****** Document ****** 7622
#  ****** Document ****** 7623
#  ****** Document ****** 7624
# 16th  not in WE, adding it with random vector
#  ****** Document ****** 7625
#  ****** Document ****** 7626
#  ****** Document ****** 7627
# 75th  not in WE, adding it with random vector
# 1915-1923  not in WE, adding it with random vector
#  ****** Document ****** 7628
#  ****** Document ****** 7629
#  ****** Document ****** 7630
#  ****** Document ****** 7631
#  ****** Document ****** 7632
#  ****** Document ****** 7633
#  ****** Document ****** 7634
#  ****** Document ****** 7635
#  ****** Document ****** 7636
#  ****** Document ****** 7637
# anti-Turkish  not in WE, adding it with random vector
# Judeo-Christian  not in WE, adding it with random vector
#  ****** Document ****** 7638
#  ****** Document ****** 7639
#  ****** Document ****** 7640
#  ****** Document ****** 7641
#  ****** Document ****** 7642
#  ****** Document ****** 7643
#  ****** Document ****** 7644
#  ****** Document ****** 7645
#  ****** Document ****** 7646
#  ****** Document ****** 7647
#  ****** Document ****** 7648
#  ****** Document ****** 7649
#  ****** Document ****** 7650
#  ****** Document ****** 7651
#  ****** Document ****** 7652
#  ****** Document ****** 7653
#  ****** Document ****** 7654
#  ****** Document ****** 7655
#  ****** Document ****** 7656
#  ****** Document ****** 7657
#  ****** Document ****** 7658
#  ****** Document ****** 7659
#  ****** Document ****** 7660
#  ****** Document ****** 7661
#  ****** Document ****** 7662
#  ****** Document ****** 7663
#  ****** Document ****** 7664
# 18-story  not in WE, adding it with random vector
#  ****** Document ****** 7665
#  ****** Document ****** 7666
# 'n'  not in WE, adding it with random vector
#  ****** Document ****** 7667
#  ****** Document ****** 7668
#  ****** Document ****** 7669
#  ****** Document ****** 7670
# gentleladies  not in WE, adding it with random vector
#  ****** Document ****** 7671
#  ****** Document ****** 7672
#  ****** Document ****** 7673
#  ****** Document ****** 7674
#  ****** Document ****** 7675
#  ****** Document ****** 7676
#  ****** Document ****** 7677
#  ****** Document ****** 7678
# neighbhorhoods  not in WE, adding it with random vector
#  ****** Document ****** 7679
#  ****** Document ****** 7680
#  ****** Document ****** 7681
#  ****** Document ****** 7682
#  ****** Document ****** 7683
# three-year-old  not in WE, adding it with random vector
#  ****** Document ****** 7684
#  ****** Document ****** 7685
# inner-city  not in WE, adding it with random vector
#  ****** Document ****** 7686
#  ****** Document ****** 7687
#  ****** Document ****** 7688
#  ****** Document ****** 7689
#  ****** Document ****** 7690
#  ****** Document ****** 7691
# A.F.  not in WE, adding it with random vector
#  ****** Document ****** 7692
#  ****** Document ****** 7693
#  ****** Document ****** 7694
#  ****** Document ****** 7695
#  ****** Document ****** 7696
#  ****** Document ****** 7697
#  ****** Document ****** 7698
#  ****** Document ****** 7699
# Reagan-Bush  not in WE, adding it with random vector
#  ****** Document ****** 7700
#  ****** Document ****** 7701
#  ****** Document ****** 7702
#  ****** Document ****** 7703
#  ****** Document ****** 7704
#  ****** Document ****** 7705
#  ****** Document ****** 7706
# non-financial  not in WE, adding it with random vector
#  ****** Document ****** 7707
# 1965  not in WE, adding it with random vector
#  ****** Document ****** 7708
#  ****** Document ****** 7709
#  ****** Document ****** 7710
#  ****** Document ****** 7711
#  ****** Document ****** 7712
#  ****** Document ****** 7713
#  ****** Document ****** 7714
#  ****** Document ****** 7715
#  ****** Document ****** 7716
#  ****** Document ****** 7717
#  ****** Document ****** 7718
# 68.9  not in WE, adding it with random vector
#  ****** Document ****** 7719
#  ****** Document ****** 7720
# mid-1980s  not in WE, adding it with random vector
#  ****** Document ****** 7721
#  ****** Document ****** 7722
#  ****** Document ****** 7723
#  ****** Document ****** 7724
# 517  not in WE, adding it with random vector
#  ****** Document ****** 7725
# Left-stream  not in WE, adding it with random vector
#  ****** Document ****** 7726
#  ****** Document ****** 7727
# high-interest  not in WE, adding it with random vector
#  ****** Document ****** 7728
#  ****** Document ****** 7729
#  ****** Document ****** 7730
#  ****** Document ****** 7731
#  ****** Document ****** 7732
#  ****** Document ****** 7733
#  ****** Document ****** 7734
#  ****** Document ****** 7735
#  ****** Document ****** 7736
#  ****** Document ****** 7737
#  ****** Document ****** 7738
# 198.41  not in WE, adding it with random vector
# 169.28  not in WE, adding it with random vector
#  ****** Document ****** 7739
#  ****** Document ****** 7740
#  ****** Document ****** 7741
#  ****** Document ****** 7742
#  ****** Document ****** 7743
#  ****** Document ****** 7744
#  ****** Document ****** 7745
#  ****** Document ****** 7746
#  ****** Document ****** 7747
#  ****** Document ****** 7748
#  ****** Document ****** 7749
#  ****** Document ****** 7750
#  ****** Document ****** 7751
# ground-cargo  not in WE, adding it with random vector
# air-cargo  not in WE, adding it with random vector
#  ****** Document ****** 7752
#  ****** Document ****** 7753
#  ****** Document ****** 7754
#  ****** Document ****** 7755
#  ****** Document ****** 7756
#  ****** Document ****** 7757
#  ****** Document ****** 7758
#  ****** Document ****** 7759
#  ****** Document ****** 7760
#  ****** Document ****** 7761
#  ****** Document ****** 7762
#  ****** Document ****** 7763
#  ****** Document ****** 7764
#  ****** Document ****** 7765
#  ****** Document ****** 7766
#  ****** Document ****** 7767
#  ****** Document ****** 7768
# far-reaching  not in WE, adding it with random vector
#  ****** Document ****** 7769
# ground-handling  not in WE, adding it with random vector
#  ****** Document ****** 7770
#  ****** Document ****** 7771
# 747  not in WE, adding it with random vector
#  ****** Document ****** 7772
#  ****** Document ****** 7773
#  ****** Document ****** 7774
#  ****** Document ****** 7775
#  ****** Document ****** 7776
#  ****** Document ****** 7777
#  ****** Document ****** 7778
#  ****** Document ****** 7779
#  ****** Document ****** 7780
#  ****** Document ****** 7781
#  ****** Document ****** 7782
#  ****** Document ****** 7783
#  ****** Document ****** 7784
#  ****** Document ****** 7785
#  ****** Document ****** 7786
# Pacific-listed  not in WE, adding it with random vector
#  ****** Document ****** 7787
#  ****** Document ****** 7788
# market-making  not in WE, adding it with random vector
#  ****** Document ****** 7789
#  ****** Document ****** 7790
#  ****** Document ****** 7791
# 129  not in WE, adding it with random vector
#  ****** Document ****** 7792
#  ****** Document ****** 7793
#  ****** Document ****** 7794
#  ****** Document ****** 7795
#  ****** Document ****** 7796
#  ****** Document ****** 7797
#  ****** Document ****** 7798
#  ****** Document ****** 7799
#  ****** Document ****** 7800
#  ****** Document ****** 7801
#  ****** Document ****** 7802
#  ****** Document ****** 7803
#  ****** Document ****** 7804
#  ****** Document ****** 7805
#  ****** Document ****** 7806
#  ****** Document ****** 7807
#  ****** Document ****** 7808
#  ****** Document ****** 7809
#  ****** Document ****** 7810
#  ****** Document ****** 7811
#  ****** Document ****** 7812
# Quotron  not in WE, adding it with random vector
#  ****** Document ****** 7813
#  ****** Document ****** 7814
# Call-In  not in WE, adding it with random vector
#  ****** Document ****** 7815
#  ****** Document ****** 7816
#  ****** Document ****** 7817
#  ****** Document ****** 7818
#  ****** Document ****** 7819
#  ****** Document ****** 7820
#  ****** Document ****** 7821
#  ****** Document ****** 7822
#  ****** Document ****** 7823
#  ****** Document ****** 7824
# 130.875  not in WE, adding it with random vector
#  ****** Document ****** 7825
# 101.75  not in WE, adding it with random vector
#  ****** Document ****** 7826
#  ****** Document ****** 7827
#  ****** Document ****** 7828
#  ****** Document ****** 7829
# well-publicized  not in WE, adding it with random vector
#  ****** Document ****** 7830
# 4.47  not in WE, adding it with random vector
#  ****** Document ****** 7831
#  ****** Document ****** 7832
#  ****** Document ****** 7833
#  ****** Document ****** 7834
#  ****** Document ****** 7835
# 580  not in WE, adding it with random vector
#  ****** Document ****** 7836
#  ****** Document ****** 7837
# 4.84-a-share  not in WE, adding it with random vector
#  ****** Document ****** 7838
#  ****** Document ****** 7839
#  ****** Document ****** 7840
#  ****** Document ****** 7841
# high-end  not in WE, adding it with random vector
#  ****** Document ****** 7842
#  ****** Document ****** 7843
#  ****** Document ****** 7844
#  ****** Document ****** 7845
# 5.81  not in WE, adding it with random vector
# 9.80  not in WE, adding it with random vector
#  ****** Document ****** 7846
#  ****** Document ****** 7847
#  ****** Document ****** 7848
#  ****** Document ****** 7849
# construction-related  not in WE, adding it with random vector
#  ****** Document ****** 7850
# post-quake  not in WE, adding it with random vector
#  ****** Document ****** 7851
#  ****** Document ****** 7852
# event-driven  not in WE, adding it with random vector
#  ****** Document ****** 7853
# 86.50  not in WE, adding it with random vector
# 37.75  not in WE, adding it with random vector
# 102.625  not in WE, adding it with random vector
# 62.50  not in WE, adding it with random vector
#  ****** Document ****** 7854
#  ****** Document ****** 7855
#  ****** Document ****** 7856
#  ****** Document ****** 7857
# cement-makers  not in WE, adding it with random vector
# Calmat  not in WE, adding it with random vector
# 28.75  not in WE, adding it with random vector
# 29.25  not in WE, adding it with random vector
#  ****** Document ****** 7858
# 2.125  not in WE, adding it with random vector
# 9.875  not in WE, adding it with random vector
# 61.875  not in WE, adding it with random vector
# 2.25  not in WE, adding it with random vector
# 44.125  not in WE, adding it with random vector
#  ****** Document ****** 7859
# 33.375  not in WE, adding it with random vector
#  ****** Document ****** 7860
# home-building  not in WE, adding it with random vector
#  ****** Document ****** 7861
#  ****** Document ****** 7862
# 43.75  not in WE, adding it with random vector
#  ****** Document ****** 7863
#  ****** Document ****** 7864
#  ****** Document ****** 7865
# 20.125  not in WE, adding it with random vector
#  ****** Document ****** 7866
#  ****** Document ****** 7867
# 81.50  not in WE, adding it with random vector
# 31.875  not in WE, adding it with random vector
#  ****** Document ****** 7868
#  ****** Document ****** 7869
#  ****** Document ****** 7870
# 19.625  not in WE, adding it with random vector
#  ****** Document ****** 7871
#  ****** Document ****** 7872
# 44.625  not in WE, adding it with random vector
#  ****** Document ****** 7873
#  ****** Document ****** 7874
# property-casualty  not in WE, adding it with random vector
#  ****** Document ****** 7875
#  ****** Document ****** 7876
#  ****** Document ****** 7877
#  ****** Document ****** 7878
#  ****** Document ****** 7879
#  ****** Document ****** 7880
#  ****** Document ****** 7881
#  ****** Document ****** 7882
#  ****** Document ****** 7883
#  ****** Document ****** 7884
#  ****** Document ****** 7885
#  ****** Document ****** 7886
#  ****** Document ****** 7887
#  ****** Document ****** 7888
# post-World  not in WE, adding it with random vector
#  ****** Document ****** 7889
#  ****** Document ****** 7890
# mild-mannered  not in WE, adding it with random vector
#  ****** Document ****** 7891
#  ****** Document ****** 7892
# money-saving  not in WE, adding it with random vector
#  ****** Document ****** 7893
#  ****** Document ****** 7894
# double-coupon  not in WE, adding it with random vector
#  ****** Document ****** 7895
#  ****** Document ****** 7896
# artery-clogging  not in WE, adding it with random vector
#  ****** Document ****** 7897
#  ****** Document ****** 7898
#  ****** Document ****** 7899
#  ****** Document ****** 7900
#  ****** Document ****** 7901
# old-fashioned  not in WE, adding it with random vector
#  ****** Document ****** 7902
#  ****** Document ****** 7903
# image-building  not in WE, adding it with random vector
#  ****** Document ****** 7904
#  ****** Document ****** 7905
#  ****** Document ****** 7906
#  ****** Document ****** 7907
#  ****** Document ****** 7908
#  ****** Document ****** 7909
#  ****** Document ****** 7910
#  ****** Document ****** 7911
#  ****** Document ****** 7912
#  ****** Document ****** 7913
#  ****** Document ****** 7914
#  ****** Document ****** 7915
#  ****** Document ****** 7916
#  ****** Document ****** 7917
#  ****** Document ****** 7918
# 31-year-old  not in WE, adding it with random vector
#  ****** Document ****** 7919
#  ****** Document ****** 7920
#  ****** Document ****** 7921
#  ****** Document ****** 7922
#  ****** Document ****** 7923
# trash-bag  not in WE, adding it with random vector
#  ****** Document ****** 7924
#  ****** Document ****** 7925
#  ****** Document ****** 7926
#  ****** Document ****** 7927
#  ****** Document ****** 7928
#  ****** Document ****** 7929
#  ****** Document ****** 7930
# one-fourth  not in WE, adding it with random vector
#  ****** Document ****** 7931
# Higher-income  not in WE, adding it with random vector
#  ****** Document ****** 7932
#  ****** Document ****** 7933
#  ****** Document ****** 7934
#  ****** Document ****** 7935
# FCB\/Leber  not in WE, adding it with random vector
#  ****** Document ****** 7936
#  ****** Document ****** 7937
#  ****** Document ****** 7938
#  ****** Document ****** 7939
#  ****** Document ****** 7940
#  ****** Document ****** 7941
#  ****** Document ****** 7942
#  ****** Document ****** 7943
#  ****** Document ****** 7944
#  ****** Document ****** 7945
#  ****** Document ****** 7946
#  ****** Document ****** 7947
#  ****** Document ****** 7948
#  ****** Document ****** 7949
#  ****** Document ****** 7950
#  ****** Document ****** 7951
#  ****** Document ****** 7952
# direct-marketing  not in WE, adding it with random vector
#  ****** Document ****** 7953
#  ****** Document ****** 7954
#  ****** Document ****** 7955
#  ****** Document ****** 7956
#  ****** Document ****** 7957
#  ****** Document ****** 7958
#  ****** Document ****** 7959
#  ****** Document ****** 7960
#  ****** Document ****** 7961
#  ****** Document ****** 7962
#  ****** Document ****** 7963
#  ****** Document ****** 7964
# non-user  not in WE, adding it with random vector
#  ****** Document ****** 7965
#  ****** Document ****** 7966
#  ****** Document ****** 7967
#  ****** Document ****** 7968
#  ****** Document ****** 7969
#  ****** Document ****** 7970
#  ****** Document ****** 7971
#  ****** Document ****** 7972
#  ****** Document ****** 7973
# price-cutting  not in WE, adding it with random vector
#  ****** Document ****** 7974
# insurance-company  not in WE, adding it with random vector
#  ****** Document ****** 7975
#  ****** Document ****** 7976
#  ****** Document ****** 7977
#  ****** Document ****** 7978
#  ****** Document ****** 7979
# claims-processing  not in WE, adding it with random vector
#  ****** Document ****** 7980
#  ****** Document ****** 7981
#  ****** Document ****** 7982
# personal-property  not in WE, adding it with random vector
#  ****** Document ****** 7983
#  ****** Document ****** 7984
#  ****** Document ****** 7985
#  ****** Document ****** 7986
#  ****** Document ****** 7987
# property-claim  not in WE, adding it with random vector
#  ****** Document ****** 7988
#  ****** Document ****** 7989
#  ****** Document ****** 7990
#  ****** Document ****** 7991
#  ****** Document ****** 7992
#  ****** Document ****** 7993
#  ****** Document ****** 7994
# Earthquake-related  not in WE, adding it with random vector
#  ****** Document ****** 7995
#  ****** Document ****** 7996
#  ****** Document ****** 7997
#  ****** Document ****** 7998
#  ****** Document ****** 7999
#  ****** Document ****** 8000
#  ****** Document ****** 8001
#  ****** Document ****** 8002
# 2.375  not in WE, adding it with random vector
# 59.50  not in WE, adding it with random vector
# 3.125  not in WE, adding it with random vector
# 75.875  not in WE, adding it with random vector
#  ****** Document ****** 8003
#  ****** Document ****** 8004
#  ****** Document ****** 8005
#  ****** Document ****** 8006
#  ****** Document ****** 8007
#  ****** Document ****** 8008
#  ****** Document ****** 8009
#  ****** Document ****** 8010
#  ****** Document ****** 8011
#  ****** Document ****** 8012
#  ****** Document ****** 8013
#  ****** Document ****** 8014
# 86.4  not in WE, adding it with random vector
# 44.3  not in WE, adding it with random vector
#  ****** Document ****** 8015
# 23.25  not in WE, adding it with random vector
#  ****** Document ****** 8016
#  ****** Document ****** 8017
#  ****** Document ****** 8018
#  ****** Document ****** 8019
#  ****** Document ****** 8020
#  ****** Document ****** 8021
# luxury-car  not in WE, adding it with random vector
#  ****** Document ****** 8022
# Motorfair  not in WE, adding it with random vector
#  ****** Document ****** 8023
# tie-up  not in WE, adding it with random vector
# high-volume  not in WE, adding it with random vector
#  ****** Document ****** 8024
#  ****** Document ****** 8025
#  ****** Document ****** 8026
#  ****** Document ****** 8027
#  ****** Document ****** 8028
#  ****** Document ****** 8029
#  ****** Document ****** 8030
#  ****** Document ****** 8031
#  ****** Document ****** 8032
#  ****** Document ****** 8033
# know-how  not in WE, adding it with random vector
#  ****** Document ****** 8034
#  ****** Document ****** 8035
# 6.30  not in WE, adding it with random vector
#  ****** Document ****** 8036
# 405  not in WE, adding it with random vector
#  ****** Document ****** 8037
#  ****** Document ****** 8038
# executive-model  not in WE, adding it with random vector
#  ****** Document ****** 8039
#  ****** Document ****** 8040
# 39,400  not in WE, adding it with random vector
# 16,000  not in WE, adding it with random vector
# highest-priced  not in WE, adding it with random vector
# hand-crafted  not in WE, adding it with random vector
#  ****** Document ****** 8041
#  ****** Document ****** 8042
#  ****** Document ****** 8043
#  ****** Document ****** 8044
# auto-industry  not in WE, adding it with random vector
#  ****** Document ****** 8045
#  ****** Document ****** 8046
#  ****** Document ****** 8047
#  ****** Document ****** 8048
#  ****** Document ****** 8049
# takeover-stock  not in WE, adding it with random vector
#  ****** Document ****** 8050
# full-fledged  not in WE, adding it with random vector
#  ****** Document ****** 8051
#  ****** Document ****** 8052
#  ****** Document ****** 8053
#  ****** Document ****** 8054
#  ****** Document ****** 8055
#  ****** Document ****** 8056
#  ****** Document ****** 8057
#  ****** Document ****** 8058
#  ****** Document ****** 8059
#  ****** Document ****** 8060
#  ****** Document ****** 8061
# 162,000  not in WE, adding it with random vector
#  ****** Document ****** 8062
# 3.55  not in WE, adding it with random vector
# 3.46  not in WE, adding it with random vector
#  ****** Document ****** 8063
# 2.78  not in WE, adding it with random vector
# 2.69  not in WE, adding it with random vector
#  ****** Document ****** 8064
# 10.3  not in WE, adding it with random vector
#  ****** Document ****** 8065
#  ****** Document ****** 8066
# 481  not in WE, adding it with random vector
#  ****** Document ****** 8067
#  ****** Document ****** 8068
#  ****** Document ****** 8069
#  ****** Document ****** 8070
# 402,000  not in WE, adding it with random vector
# 80,000  not in WE, adding it with random vector
# 62.3  not in WE, adding it with random vector
#  ****** Document ****** 8071
# 2.55  not in WE, adding it with random vector
# 2.51  not in WE, adding it with random vector
#  ****** Document ****** 8072
# 2.04  not in WE, adding it with random vector
#  ****** Document ****** 8073
#  ****** Document ****** 8074
#  ****** Document ****** 8075
#  ****** Document ****** 8076
#  ****** Document ****** 8077
#  ****** Document ****** 8078
# door-to-door  not in WE, adding it with random vector
#  ****** Document ****** 8079
#  ****** Document ****** 8080
# 2,064  not in WE, adding it with random vector
#  ****** Document ****** 8081
# 2,002  not in WE, adding it with random vector
#  ****** Document ****** 8082
#  ****** Document ****** 8083
#  ****** Document ****** 8084
#  ****** Document ****** 8085
#  ****** Document ****** 8086
#  ****** Document ****** 8087
#  ****** Document ****** 8088
# computer-guided  not in WE, adding it with random vector
#  ****** Document ****** 8089
#  ****** Document ****** 8090
#  ****** Document ****** 8091
#  ****** Document ****** 8092
#  ****** Document ****** 8093
#  ****** Document ****** 8094
#  ****** Document ****** 8095
#  ****** Document ****** 8096
#  ****** Document ****** 8097
#  ****** Document ****** 8098
#  ****** Document ****** 8099
#  ****** Document ****** 8100
#  ****** Document ****** 8101
#  ****** Document ****** 8102
# program-trading  not in WE, adding it with random vector
#  ****** Document ****** 8103
#  ****** Document ****** 8104
#  ****** Document ****** 8105
#  ****** Document ****** 8106
#  ****** Document ****** 8107
#  ****** Document ****** 8108
# re-establish  not in WE, adding it with random vector
#  ****** Document ****** 8109
#  ****** Document ****** 8110
# 63.52  not in WE, adding it with random vector
#  ****** Document ****** 8111
# 10:10  not in WE, adding it with random vector
#  ****** Document ****** 8112
# 88.12  not in WE, adding it with random vector
#  ****** Document ****** 8113
# boutique-store  not in WE, adding it with random vector
#  ****** Document ****** 8114
#  ****** Document ****** 8115
#  ****** Document ****** 8116
# Phoenix-based  not in WE, adding it with random vector
# 121  not in WE, adding it with random vector
#  ****** Document ****** 8117
#  ****** Document ****** 8118
# 136.4  not in WE, adding it with random vector
#  ****** Document ****** 8119
# 48.6  not in WE, adding it with random vector
# 2.46  not in WE, adding it with random vector
#  ****** Document ****** 8120
#  ****** Document ****** 8121
#  ****** Document ****** 8122
#  ****** Document ****** 8123
#  ****** Document ****** 8124
# 199.7  not in WE, adding it with random vector
#  ****** Document ****** 8125
# write-down  not in WE, adding it with random vector
#  ****** Document ****** 8126
# write-downs  not in WE, adding it with random vector
#  ****** Document ****** 8127
#  ****** Document ****** 8128
#  ****** Document ****** 8129
#  ****** Document ****** 8130
# 24.25  not in WE, adding it with random vector
#  ****** Document ****** 8131
#  ****** Document ****** 8132
#  ****** Document ****** 8133
# hard-earned  not in WE, adding it with random vector
#  ****** Document ****** 8134
#  ****** Document ****** 8135
#  ****** Document ****** 8136
#  ****** Document ****** 8137
#  ****** Document ****** 8138
#  ****** Document ****** 8139
#  ****** Document ****** 8140
#  ****** Document ****** 8141
#  ****** Document ****** 8142
# post-crash  not in WE, adding it with random vector
#  ****** Document ****** 8143
#  ****** Document ****** 8144
#  ****** Document ****** 8145
#  ****** Document ****** 8146
#  ****** Document ****** 8147
# individual-investor  not in WE, adding it with random vector
#  ****** Document ****** 8148
# bull-market  not in WE, adding it with random vector
#  ****** Document ****** 8149
#  ****** Document ****** 8150
#  ****** Document ****** 8151
# cash-equivalent  not in WE, adding it with random vector
#  ****** Document ****** 8152
#  ****** Document ****** 8153
#  ****** Document ****** 8154
#  ****** Document ****** 8155
# 21.4  not in WE, adding it with random vector
#  ****** Document ****** 8156
# 18.2  not in WE, adding it with random vector
#  ****** Document ****** 8157
# 23.5  not in WE, adding it with random vector
#  ****** Document ****** 8158
# retail-volume  not in WE, adding it with random vector
# buy-backs  not in WE, adding it with random vector
#  ****** Document ****** 8159
#  ****** Document ****** 8160
#  ****** Document ****** 8161
#  ****** Document ****** 8162
#  ****** Document ****** 8163
#  ****** Document ****** 8164
#  ****** Document ****** 8165
#  ****** Document ****** 8166
#  ****** Document ****** 8167
#  ****** Document ****** 8168
#  ****** Document ****** 8169
#  ****** Document ****** 8170
#  ****** Document ****** 8171
#  ****** Document ****** 8172
#  ****** Document ****** 8173
#  ****** Document ****** 8174
#  ****** Document ****** 8175
#  ****** Document ****** 8176
#  ****** Document ****** 8177
#  ****** Document ****** 8178
# 6.15  not in WE, adding it with random vector
#  ****** Document ****** 8179
#  ****** Document ****** 8180
# MIG-1  not in WE, adding it with random vector
#  ****** Document ****** 8181
#  ****** Document ****** 8182
#  ****** Document ****** 8183
#  ****** Document ****** 8184
# 1989-83  not in WE, adding it with random vector
#  ****** Document ****** 8185
# at-market  not in WE, adding it with random vector
#  ****** Document ****** 8186
#  ****** Document ****** 8187
# 1989-84  not in WE, adding it with random vector
#  ****** Document ****** 8188
#  ****** Document ****** 8189
#  ****** Document ****** 8190
# Azioni  not in WE, adding it with random vector
# Manaifatturiera  not in WE, adding it with random vector
#  ****** Document ****** 8191
# 101.60  not in WE, adding it with random vector
# 9.07  not in WE, adding it with random vector
#  ****** Document ****** 8192
#  ****** Document ****** 8193
#  ****** Document ****** 8194
# 8.74  not in WE, adding it with random vector
#  ****** Document ****** 8195
#  ****** Document ****** 8196
#  ****** Document ****** 8197
# floating-rate  not in WE, adding it with random vector
# 3\/16  not in WE, adding it with random vector
#  ****** Document ****** 8198
#  ****** Document ****** 8199
# 0.36  not in WE, adding it with random vector
#  ****** Document ****** 8200
#  ****** Document ****** 8201
#  ****** Document ****** 8202
#  ****** Document ****** 8203
# 0.375  not in WE, adding it with random vector
#  ****** Document ****** 8204
#  ****** Document ****** 8205
#  ****** Document ****** 8206
#  ****** Document ****** 8207
# equity-purchase  not in WE, adding it with random vector
#  ****** Document ****** 8208
#  ****** Document ****** 8209
# Seiren  not in WE, adding it with random vector
#  ****** Document ****** 8210
#  ****** Document ****** 8211
# 3.865  not in WE, adding it with random vector
#  ****** Document ****** 8212
#  ****** Document ****** 8213
#  ****** Document ****** 8214
#  ****** Document ****** 8215
#  ****** Document ****** 8216
# 3.846  not in WE, adding it with random vector
#  ****** Document ****** 8217
#  ****** Document ****** 8218
#  ****** Document ****** 8219
# 7.86  not in WE, adding it with random vector
#  ****** Document ****** 8220
#  ****** Document ****** 8221
#  ****** Document ****** 8222
# four-part  not in WE, adding it with random vector
#  ****** Document ****** 8223
# 95.2  not in WE, adding it with random vector
#  ****** Document ****** 8224
# two-part  not in WE, adding it with random vector
#  ****** Document ****** 8225
# 98.481  not in WE, adding it with random vector
# 13.75  not in WE, adding it with random vector
#  ****** Document ****** 8226
# 87.026  not in WE, adding it with random vector
# 15.25  not in WE, adding it with random vector
#  ****** Document ****** 8227
# ...
#  ****** TEST Document ****** 10661
#  ****** TEST Document ****** 10662
#  ****** TEST Document ****** 10663
# 140.95  not in WE, adding it with random vector
#  ****** TEST Document ****** 10664
# 1.8435  not in WE, adding it with random vector
#  ****** TEST Document ****** 10665
# 141  not in WE, adding it with random vector
#  ****** TEST Document ****** 10666
#  ****** TEST Document ****** 10667
#  ****** TEST Document ****** 10668
#  ****** TEST Document ****** 10669
#  ****** TEST Document ****** 10670
#  ****** TEST Document ****** 10671
#  ****** TEST Document ****** 10672
#  ****** TEST Document ****** 10673
#  ****** TEST Document ****** 10674
# currencny  not in WE, adding it with random vector
#  ****** TEST Document ****** 10675
# 141.85  not in WE, adding it with random vector
#  ****** TEST Document ****** 10676
# 1.5753  not in WE, adding it with random vector
#  ****** TEST Document ****** 10677
# 142.55  not in WE, adding it with random vector
#  ****** TEST Document ****** 10678
# 142.25  not in WE, adding it with random vector
#  ****** TEST Document ****** 10679
#  ****** TEST Document ****** 10680
#  ****** TEST Document ****** 10681
#  ****** TEST Document ****** 10682
#  ****** TEST Document ****** 10683
#  ****** TEST Document ****** 10684
#  ****** TEST Document ****** 10685
#  ****** TEST Document ****** 10686
#  ****** TEST Document ****** 10687
#  ****** TEST Document ****** 10688
#  ****** TEST Document ****** 10689
#  ****** TEST Document ****** 10690
# 367.40  not in WE, adding it with random vector
#  ****** TEST Document ****** 10691
#  ****** TEST Document ****** 10692
# 366.55  not in WE, adding it with random vector
#  ****** TEST Document ****** 10693
#  ****** TEST Document ****** 10694
#  ****** TEST Document ****** 10695
#  ****** TEST Document ****** 10696
#  ****** TEST Document ****** 10697
#  ****** TEST Document ****** 10698
#  ****** TEST Document ****** 10699
#  ****** TEST Document ****** 10700
# record-breaking  not in WE, adding it with random vector
# 68-week  not in WE, adding it with random vector
# ABC-TV  not in WE, adding it with random vector
#  ****** TEST Document ****** 10701
#  ****** TEST Document ****** 10702
# 13.9  not in WE, adding it with random vector
#  ****** TEST Document ****** 10703
# 904,000  not in WE, adding it with random vector
#  ****** TEST Document ****** 10704
# 18th  not in WE, adding it with random vector
#  ****** TEST Document ****** 10705
# highest-rated  not in WE, adding it with random vector
#  ****** TEST Document ****** 10706
#  ****** TEST Document ****** 10707
# 1962-63  not in WE, adding it with random vector
#  ****** TEST Document ****** 10708
#  ****** TEST Document ****** 10709
#  ****** TEST Document ****** 10710
# Butter-Nut  not in WE, adding it with random vector
#  ****** TEST Document ****** 10711
#  ****** TEST Document ****** 10712
#  ****** TEST Document ****** 10713
#  ****** TEST Document ****** 10714
#  ****** TEST Document ****** 10715
#  ****** TEST Document ****** 10716
# coffee-roasting  not in WE, adding it with random vector
#  ****** TEST Document ****** 10717
# BLOEDEL  not in WE, adding it with random vector
#  ****** TEST Document ****** 10718
#  ****** TEST Document ****** 10719
#  ****** TEST Document ****** 10720
#  ****** TEST Document ****** 10721
#  ****** TEST Document ****** 10722
#  ****** TEST Document ****** 10723
#  ****** TEST Document ****** 10724
#  ****** TEST Document ****** 10725
#  ****** TEST Document ****** 10726
#  ****** TEST Document ****** 10727
#  ****** TEST Document ****** 10728
#  ****** TEST Document ****** 10729
#  ****** TEST Document ****** 10730
#  ****** TEST Document ****** 10731
#  ****** TEST Document ****** 10732
#  ****** TEST Document ****** 10733
#  ****** TEST Document ****** 10734
#  ****** TEST Document ****** 10735
# 105.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10736
# investment-bank  not in WE, adding it with random vector
# securities-firm  not in WE, adding it with random vector
#  ****** TEST Document ****** 10737
#  ****** TEST Document ****** 10738
#  ****** TEST Document ****** 10739
#  ****** TEST Document ****** 10740
#  ****** TEST Document ****** 10741
#  ****** TEST Document ****** 10742
#  ****** TEST Document ****** 10743
# MicroGeneSys  not in WE, adding it with random vector
#  ****** TEST Document ****** 10744
# VaxSyn  not in WE, adding it with random vector
# HIV-1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10745
# innoculating  not in WE, adding it with random vector
#  ****** TEST Document ****** 10746
#  ****** TEST Document ****** 10747
#  ****** TEST Document ****** 10748
#  ****** TEST Document ****** 10749
#  ****** TEST Document ****** 10750
#  ****** TEST Document ****** 10751
#  ****** TEST Document ****** 10752
#  ****** TEST Document ****** 10753
# machine-tool  not in WE, adding it with random vector
#  ****** TEST Document ****** 10754
#  ****** TEST Document ****** 10755
# RobertsCorp  not in WE, adding it with random vector
#  ****** TEST Document ****** 10756
# 8.292  not in WE, adding it with random vector
# 91-day  not in WE, adding it with random vector
# 8.483  not in WE, adding it with random vector
#  ****** TEST Document ****** 10757
#  ****** TEST Document ****** 10758
# 7.986  not in WE, adding it with random vector
# 182-day  not in WE, adding it with random vector
# 8.1255  not in WE, adding it with random vector
#  ****** TEST Document ****** 10759
# 415  not in WE, adding it with random vector
#  ****** TEST Document ****** 10760
#  ****** TEST Document ****** 10761
#  ****** TEST Document ****** 10762
# 38.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10763
# 378  not in WE, adding it with random vector
#  ****** TEST Document ****** 10764
# 163  not in WE, adding it with random vector
#  ****** TEST Document ****** 10765
#  ****** TEST Document ****** 10766
# 199  not in WE, adding it with random vector
#  ****** TEST Document ****** 10767
# 10.16  not in WE, adding it with random vector
# 8.85  not in WE, adding it with random vector
#  ****** TEST Document ****** 10768
# N.D  not in WE, adding it with random vector
#  ****** TEST Document ****** 10769
#  ****** TEST Document ****** 10770
#  ****** TEST Document ****** 10771
#  ****** TEST Document ****** 10772
#  ****** TEST Document ****** 10773
#  ****** TEST Document ****** 10774
#  ****** TEST Document ****** 10775
#  ****** TEST Document ****** 10776
# 60.7  not in WE, adding it with random vector
# 2.32  not in WE, adding it with random vector
#  ****** TEST Document ****** 10777
# 601.3  not in WE, adding it with random vector
# 618.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10778
#  ****** TEST Document ****** 10779
#  ****** TEST Document ****** 10780
#  ****** TEST Document ****** 10781
# vinyl-products  not in WE, adding it with random vector
# 30.1  not in WE, adding it with random vector
# 64.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10782
# specialty-chemicals  not in WE, adding it with random vector
# 24.3  not in WE, adding it with random vector
#  ****** TEST Document ****** 10783
#  ****** TEST Document ****** 10784
# Ohio-based  not in WE, adding it with random vector
# 49.125  not in WE, adding it with random vector
#  ****** TEST Document ****** 10785
#  ****** TEST Document ****** 10786
#  ****** TEST Document ****** 10787
#  ****** TEST Document ****** 10788
#  ****** TEST Document ****** 10789
#  ****** TEST Document ****** 10790
#  ****** TEST Document ****** 10791
#  ****** TEST Document ****** 10792
#  ****** TEST Document ****** 10793
#  ****** TEST Document ****** 10794
#  ****** TEST Document ****** 10795
#  ****** TEST Document ****** 10796
#  ****** TEST Document ****** 10797
#  ****** TEST Document ****** 10798
#  ****** TEST Document ****** 10799
#  ****** TEST Document ****** 10800
#  ****** TEST Document ****** 10801
#  ****** TEST Document ****** 10802
#  ****** TEST Document ****** 10803
#  ****** TEST Document ****** 10804
#  ****** TEST Document ****** 10805
#  ****** TEST Document ****** 10806
#  ****** TEST Document ****** 10807
#  ****** TEST Document ****** 10808
# most-active  not in WE, adding it with random vector
#  ****** TEST Document ****** 10809
#  ****** TEST Document ****** 10810
#  ****** TEST Document ****** 10811
#  ****** TEST Document ****** 10812
#  ****** TEST Document ****** 10813
#  ****** TEST Document ****** 10814
# UBS-Phillips  not in WE, adding it with random vector
#  ****** TEST Document ****** 10815
#  ****** TEST Document ****** 10816
#  ****** TEST Document ****** 10817
#  ****** TEST Document ****** 10818
# 316  not in WE, adding it with random vector
#  ****** TEST Document ****** 10819
#  ****** TEST Document ****** 10820
#  ****** TEST Document ****** 10821
#  ****** TEST Document ****** 10822
#  ****** TEST Document ****** 10823
#  ****** TEST Document ****** 10824
#  ****** TEST Document ****** 10825
#  ****** TEST Document ****** 10826
#  ****** TEST Document ****** 10827
# 12.60  not in WE, adding it with random vector
#  ****** TEST Document ****** 10828
# Seattle-based  not in WE, adding it with random vector
#  ****** TEST Document ****** 10829
# 180,000  not in WE, adding it with random vector
#  ****** TEST Document ****** 10830
#  ****** TEST Document ****** 10831
#  ****** TEST Document ****** 10832
#  ****** TEST Document ****** 10833
# C-S  not in WE, adding it with random vector
# 107,100  not in WE, adding it with random vector
#  ****** TEST Document ****** 10834
#  ****** TEST Document ****** 10835
#  ****** TEST Document ****** 10836
# JAGRY  not in WE, adding it with random vector
#  ****** TEST Document ****** 10837
#  ****** TEST Document ****** 10838
#  ****** TEST Document ****** 10839
#  ****** TEST Document ****** 10840
# 44.9  not in WE, adding it with random vector
#  ****** TEST Document ****** 10841
#  ****** TEST Document ****** 10842
# 21.2  not in WE, adding it with random vector
#  ****** TEST Document ****** 10843
# Averae  not in WE, adding it with random vector
# 182.9  not in WE, adding it with random vector
#  ****** TEST Document ****** 10844
#  ****** TEST Document ****** 10845
#  ****** TEST Document ****** 10846
#  ****** TEST Document ****** 10847
#  ****** TEST Document ****** 10848
# 49.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10849
# 11-a-share  not in WE, adding it with random vector
# electronic-measuring  not in WE, adding it with random vector
#  ****** TEST Document ****** 10850
#  ****** TEST Document ****** 10851
#  ****** TEST Document ****** 10852
#  ****** TEST Document ****** 10853
# 9.482  not in WE, adding it with random vector
# 5.80  not in WE, adding it with random vector
#  ****** TEST Document ****** 10854
# 7.567  not in WE, adding it with random vector
#  ****** TEST Document ****** 10855
#  ****** TEST Document ****** 10856
#  ****** TEST Document ****** 10857
#  ****** TEST Document ****** 10858
# 76.6  not in WE, adding it with random vector
# 120.6  not in WE, adding it with random vector
#  ****** TEST Document ****** 10859
#  ****** TEST Document ****** 10860
# 51.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10861
# 626.3  not in WE, adding it with random vector
#  ****** TEST Document ****** 10862
#  ****** TEST Document ****** 10863
# 49.6  not in WE, adding it with random vector
#  ****** TEST Document ****** 10864
# 235.2  not in WE, adding it with random vector
# 176.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10865
# 6.50  not in WE, adding it with random vector
#  ****** TEST Document ****** 10866
#  ****** TEST Document ****** 10867
# 2.875  not in WE, adding it with random vector
# 78.625  not in WE, adding it with random vector
#  ****** TEST Document ****** 10868
# 73.50  not in WE, adding it with random vector
#  ****** TEST Document ****** 10869
#  ****** TEST Document ****** 10870
#  ****** TEST Document ****** 10871
#  ****** TEST Document ****** 10872
# 21.1  not in WE, adding it with random vector
# 20.7  not in WE, adding it with random vector
#  ****** TEST Document ****** 10873
#  ****** TEST Document ****** 10874
# high-performance  not in WE, adding it with random vector
#  ****** TEST Document ****** 10875
# quarter-to-quarter  not in WE, adding it with random vector
#  ****** TEST Document ****** 10876
#  ****** TEST Document ****** 10877
#  ****** TEST Document ****** 10878
# reduced-instruction  not in WE, adding it with random vector
#  ****** TEST Document ****** 10879
#  ****** TEST Document ****** 10880
#  ****** TEST Document ****** 10881
# RISC-based  not in WE, adding it with random vector
#  ****** TEST Document ****** 10882
#  ****** TEST Document ****** 10883
# supermainframe  not in WE, adding it with random vector
# generalpurpose  not in WE, adding it with random vector
#  ****** TEST Document ****** 10884
# UAL'S  not in WE, adding it with random vector
# SKIDDED  not in WE, adding it with random vector
#  ****** TEST Document ****** 10885
# 87.25  not in WE, adding it with random vector
#  ****** TEST Document ****** 10886
# back-up  not in WE, adding it with random vector
#  ****** TEST Document ****** 10887
#  ****** TEST Document ****** 10888
#  ****** TEST Document ****** 10889
#  ****** TEST Document ****** 10890
#  ****** TEST Document ****** 10891
#  ****** TEST Document ****** 10892
#  ****** TEST Document ****** 10893
#  ****** TEST Document ****** 10894
#  ****** TEST Document ****** 10895
#  ****** TEST Document ****** 10896
#  ****** TEST Document ****** 10897
#  ****** TEST Document ****** 10898
#  ****** TEST Document ****** 10899
#  ****** TEST Document ****** 10900
#  ****** TEST Document ****** 10901
#  ****** TEST Document ****** 10902
#  ****** TEST Document ****** 10903
#  ****** TEST Document ****** 10904
#  ****** TEST Document ****** 10905
#  ****** TEST Document ****** 10906
#  ****** TEST Document ****** 10907
#  ****** TEST Document ****** 10908
#  ****** TEST Document ****** 10909
#  ****** TEST Document ****** 10910
#  ****** TEST Document ****** 10911
#  ****** TEST Document ****** 10912
#  ****** TEST Document ****** 10913
#  ****** TEST Document ****** 10914
# 214.54  not in WE, adding it with random vector
# 0.19  not in WE, adding it with random vector
#  ****** TEST Document ****** 10915
# 3377.43  not in WE, adding it with random vector
#  ****** TEST Document ****** 10916
# 129.72  not in WE, adding it with random vector
# 129.97  not in WE, adding it with random vector
#  ****** TEST Document ****** 10917
# 0.0018  not in WE, adding it with random vector
#  ****** TEST Document ****** 10918
#  ****** TEST Document ****** 10919
#  ****** TEST Document ****** 10920
#  ****** TEST Document ****** 10921
# BroadBeach  not in WE, adding it with random vector
# 62-a-share  not in WE, adding it with random vector
#  ****** TEST Document ****** 10922
# ball-bearing  not in WE, adding it with random vector
#  ****** TEST Document ****** 10923
# 72-a-share  not in WE, adding it with random vector
#  ****** TEST Document ****** 10924
# 101,000  not in WE, adding it with random vector
# 7.3  not in WE, adding it with random vector
#  ****** TEST Document ****** 10925
#  ****** TEST Document ****** 10926
#  ****** TEST Document ****** 10927
#  ****** TEST Document ****** 10928
# co-founded  not in WE, adding it with random vector
# California-based  not in WE, adding it with random vector
#  ****** TEST Document ****** 10929
#  ****** TEST Document ****** 10930
# 133.8  not in WE, adding it with random vector
# 130.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10931
# 322.7  not in WE, adding it with random vector
#  ****** TEST Document ****** 10932
# 246.6  not in WE, adding it with random vector
# 124.5  not in WE, adding it with random vector
#  ****** TEST Document ****** 10933
# newspaper-delivery  not in WE, adding it with random vector
#  ****** TEST Document ****** 10934
#  ****** TEST Document ****** 10935
# B\/T  not in WE, adding it with random vector
#  ****** TEST Document ****** 10936
#  ****** TEST Document ****** 10937
#  ****** TEST Document ****** 10938
#  ****** TEST Document ****** 10939
#  ****** TEST Document ****** 10940
#  ****** TEST Document ****** 10941
# six-year-old  not in WE, adding it with random vector
# first-ever  not in WE, adding it with random vector
#  ****** TEST Document ****** 10942
#  ****** TEST Document ****** 10943
#  ****** TEST Document ****** 10944
#  ****** TEST Document ****** 10945
#  ****** TEST Document ****** 10946
#  ****** TEST Document ****** 10947
#  ****** TEST Document ****** 10948

# %% [markdown]
# ### Add the (key-value) 'random' word embeddings for missing inputs

# %%
## YOUR CODE HERE
wv_pre_trained.add_vectors(list(dictadd.keys()), list(dictadd.values()))

# %% [markdown]
# ### Store the train and test datasets: a word embedding for each token in the sequences

# %%
wvectors = [wv_pre_trained[x] for d in alldocs for x,pos in d ]
wvectorsT = [wv_pre_trained[x] for d in alldocsT for x,pos in d ]

# %% [markdown]
# ### Check the size of your train/test datasets

# %%
## YOUR CODE HERE
print("La taille de datasets de train est de  : ",len(wvectors))
print("La taille de datasets de test est de  : ",len(wvectorsT))
# Out:
# La taille de datasets de train est de  :  211727
# La taille de datasets de test est de  :  47377

# %% [markdown]
# ### Collecting train/test labels

# %%
# Labels train/test

buf2 = [[pos for m,pos in d ] for d in alldocs]
cles = []
[cles.extend(b) for b in buf2]
cles = np.unique(np.array(cles))
cles2ind = dict(zip(cles,range(len(cles))))
nCles = len(cles)
print(nCles," keys in the dictionary")

labels  = np.array([cles2ind[pos] for d in alldocs for (m,pos) in d ])
#np.array([cles2ind[pos] for (m,pos) in d for d in alldocs])
labelsT  = np.array([cles2ind.setdefault(pos,len(cles)) for d in alldocsT for (m,pos) in d ])

print(len(cles2ind)," keys in the dictionary")
# Out:
# 22  keys in the dictionary
# 23  keys in the dictionary

# %%
print(labels.shape)
print(labelsT.shape)
# Out:
# (211727,)
# (47377,)

# %%
labelsT
# Out:
# array([ 5, 15, 15, ...,  5, 15, 21])

# %% [markdown]
# ### Train a Logistic Regression Model!
# **An compare performances to the baseline and sequence models (HMM/CRF) or practical 2a**

# %%
## YOUR CODE HERE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Scikit Logistic Regression

lr_clf = LogisticRegression()

lr_clf.fit(wvectors, labels)
pred_lrt = lr_clf.predict(wvectors)
pred_lr = lr_clf.predict(wvectorsT)
print(f"Logistic Regression accuracy train={accuracy_score(labels, pred_lrt)}, accuracy test={accuracy_score(labelsT, pred_lr)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression accuracy train=0.7754986373962697, accuracy test=0.7718724275492328

# %% [markdown]
# # 2) Using word embedding with CRF

# %% [markdown]
# ## We will define the following features functions for CRF

# %%
def features_wv(sentence, index):
    v = wv_pre_trained.get_vector(sentence[index])
    d = {'f'+str(i):v[i] for i in range(300)}
    return d

def features_structural(sentence, index):
    return {
        'word': sentence[index],
        'is_first': index == 0,
        'is_last': index == len(sentence) - 1,
        'is_capitalized': sentence[index][0].upper() == sentence[index][0],
        'is_all_caps': sentence[index].upper() == sentence[index],
        'is_all_lower': sentence[index].lower() == sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:2],
        'prefix-3': sentence[index][:3],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-2:],
        'suffix-3': sentence[index][-3:],
        'prev_word': '' if index == 0 else sentence[index - 1],
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1],
        'has_hyphen': '-' in sentence[index],
        'is_numeric': sentence[index].isdigit(),
     ## We will define the following features functions for CRF## We will define the following features functions for CRF   'capitals_inside': sentence[index][1:].lower() != sentence[index][1:]
    }
def features_wv_plus_structural(sentence, index):
    v = wv_pre_trained.get_vector(sentence[index])
    d = {'f'+str(i):v[i] for i in range(300)}

    return {**d, **features_structural(sentence, index)}

# %% [markdown]
# ## [Question]: explain what the 3 feature functions encode and what their differences are

# %% [markdown]
# **features_wv(sentence, index) :**
#
# Cette fonction extrait des caractéristiques basées sur des vecteurs de mots pré-entraînés.
# Elle récupère le vecteur de mots correspondant à un mot donné dans une phrase à partir des embeddings pré-entraînés.
# Ensuite, elle crée un dictionnaire de caractéristiques où chaque dimension du vecteur de mots est associée à une caractéristique.
#
# **features_structural(sentence, index) :**
#
# Cette fonction extrait des caractéristiques structurelles ou lexicales des mots dans une phrase.
# Les caractéristiques incluent des informations telles que la position du mot dans la phrase, s'il est en majuscules, s'il contient des caractères spéciaux, etc.
#
# **features_wv_plus_structural(sentence, index) :**
#
# Cette fonction combine les caractéristiques extraites à partir des embeddings de mots pré-entraînés et des caractéristiques structurelles.
# Elle fusionne les informations sémantiques des embeddings de mots avec les informations structurelles et lexicales des mots dans une seule représentation pour chaque mot.
#
#
# En résumé, ces fonctions permettent de capturer à la fois les informations sémantiques et structurelles des mots .

# %% [markdown]
# ### You can now train a CRF with the 3 features and analyse the results

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
# !pip install python-crfsuite
# Out:
# Collecting python-crfsuite
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite
# Successfully installed python-crfsuite-0.9.10

# %%
from nltk.tag.crf import CRFTagger
tagger = CRFTagger(feature_func=features_wv)
## Train the model
tagger.train(alldocs,'model.crf.tagger_features_wv')
## Evaluate performances
tagger.evaluate(alldocsT)
# Out:
# <ipython-input-21-8bd6ec8cbfde>:6: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   tagger.evaluate(alldocsT)
# 0.8816092196635498

# %%
tagger = CRFTagger(feature_func=features_structural)
## Train the model
tagger.train(alldocs,'model.crf.features_structural')
## Evaluate performances
tagger.evaluate((alldocsT))
# Out:
# <ipython-input-22-552cff29a9d9>:5: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   tagger.evaluate((alldocsT))
# 0.9384722544694684

# %%
tagger = CRFTagger(feature_func=features_wv_plus_structural)
## Train the model
tagger.train(alldocs,'model.crf.features_wv_plus_structural')
## Evaluate performances
tagger.evaluate((alldocsT))
# Out:
# <ipython-input-23-453769cca375>:5: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   tagger.evaluate((alldocsT))
# 0.9451632648753615
